# %% [markdown]
# # **Automating Daily Report Generation**

# %% [markdown]
# ---
#
# **Automation and Efficiency**
#
# * GOAL:
# * WHY:
# * WHAT:
# * HOW:
# * WHEN:
#
# ---

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Automating-Daily-Report-Generation" data-toc-modified-id="Automating-Daily-Report-Generation-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><strong>Automating Daily Report Generation</strong></a></span></li><li><span><a href="#Imports" data-toc-modified-id="Imports-2"><span class="toc-item-num">2&nbsp;&nbsp;</span><strong>Imports</strong></a></span></li><li><span><a href="#Read-Data" data-toc-modified-id="Read-Data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span><strong>Read Data</strong></a></span></li><li><span><a href="#EDA" data-toc-modified-id="EDA-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>EDA</a></span></li></ul></div>

# %% [markdown]
# # **Imports**

# %%
from bmcds import eda

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Read Data**

# %%
week1 = pd.read_excel('Data/Week_of_11_7_21.xlsx', header=None, usecols = 'A:I', skiprows=7)
week1
# Out:
#                               0       1       2      3       4       5  \
# 0                           283             283              0     283
# 1                          1981            1981              0    1981
# 2                          1459            1242            217     683
# 3                        0.7365          0.6271         0.1094  0.3448
# 4                        153.03          107.35          45.68     109
# ...                         ...     ...     ...    ...     ...     ...
# 1463                       1105 -0.0181    7956  0.203   -6851   25347
# 1464
# 1465                      -2658           11655         -14313   21343
# 1466
# 1467  11/29/2021 at 10:21:17 PM     NaN     NaN    NaN     NaN     NaN
#
#            6       7                             8
# 0                  0                       # Rooms
# 1                  0         Room Nights Available
# 2                776              Room Nights Sold
# 3             0.3917                   Occupancy %
# 4              44.03                           ADR
# ...      ...     ...                           ...
# 1463 -0.7941  -24242        Total Benefits Expense
# 1464
# 1465          -24001  Total PR tax/benefit expense
# 1466
# 1467             NaN                           NaN
#
# [1468 rows x 9 columns]

# %%
## 
col_names = ['Actual', '%', 'Budget', '%', 'Variance (B)', 'Last Year', '%',
 'Variance (LY)', 'Item']
col_names
# Out:
# ['Actual',
#  '%',
#  'Budget',
#  '%',
#  'Variance (B)',
#  'Last Year',
#  '%',
#  'Variance (LY)',
#  'Item']

# %%
week1.columns = col_names
week1
# Out:
#                          Actual       %  Budget      % Variance (B) Last Year  \
# 0                           283             283                   0       283
# 1                          1981            1981                   0      1981
# 2                          1459            1242                 217       683
# 3                        0.7365          0.6271              0.1094    0.3448
# 4                        153.03          107.35               45.68       109
# ...                         ...     ...     ...    ...          ...       ...
# 1463                       1105 -0.0181    7956  0.203        -6851     25347
# 1464
# 1465                      -2658           11655              -14313     21343
# 1466
# 1467  11/29/2021 at 10:21:17 PM     NaN     NaN    NaN          NaN       NaN
#
#            % Variance (LY)                          Item
# 0                        0                       # Rooms
# 1                        0         Room Nights Available
# 2                      776              Room Nights Sold
# 3                   0.3917                   Occupancy %
# 4                    44.03                           ADR
# ...      ...           ...                           ...
# 1463 -0.7941        -24242        Total Benefits Expense
# 1464
# 1465                -24001  Total PR tax/benefit expense
# 1466
# 1467                   NaN                           NaN
#
# [1468 rows x 9 columns]

# %%
week1.loc[1466,:].values
# Out:
# array([' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], dtype=object)

# %%
week1 = week1.replace(' ', np.nan)
week1
# Out:
#                          Actual       %  Budget      % Variance (B) Last Year  \
# 0                           283     NaN     283    NaN            0       283
# 1                          1981     NaN    1981    NaN            0      1981
# 2                          1459     NaN    1242    NaN          217       683
# 3                        0.7365     NaN  0.6271    NaN       0.1094    0.3448
# 4                        153.03     NaN  107.35    NaN        45.68       109
# ...                         ...     ...     ...    ...          ...       ...
# 1463                       1105 -0.0181    7956  0.203        -6851     25347
# 1464                        NaN     NaN     NaN    NaN          NaN       NaN
# 1465                      -2658     NaN   11655    NaN       -14313     21343
# 1466                        NaN     NaN     NaN    NaN          NaN       NaN
# 1467  11/29/2021 at 10:21:17 PM     NaN     NaN    NaN          NaN       NaN
#
#            % Variance (LY)                          Item
# 0        NaN             0                       # Rooms
# 1        NaN             0         Room Nights Available
# 2        NaN           776              Room Nights Sold
# 3        NaN        0.3917                   Occupancy %
# 4        NaN         44.03                           ADR
# ...      ...           ...                           ...
# 1463 -0.7941        -24242        Total Benefits Expense
# 1464     NaN           NaN                           NaN
# 1465     NaN        -24001  Total PR tax/benefit expense
# 1466     NaN           NaN                           NaN
# 1467     NaN           NaN                           NaN
#
# [1468 rows x 9 columns]

# %%
week1.isna().sum()
# Out:
# Actual           429
# %                673
# Budget           484
# %                673
# Variance (B)     457
# Last Year        484
# %                592
# Variance (LY)    457
# Item             413
# dtype: int64

# %% [markdown]
# # EDA
